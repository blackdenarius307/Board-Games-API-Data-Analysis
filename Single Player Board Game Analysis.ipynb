# %%
#Importations
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

#Board Game Info
Boardgame_path = "Board-Games_Group-F-PlayerCountList.csv"

#Read the CSV
Boardgame_df = pd.read_csv(Boardgame_path)

# %%
Totalgames = len(Boardgame_df)
Single_player_df = Boardgame_df[Boardgame_df['min_players'] == 1.0]
Totalsingleplayer = len(Single_player_df)
Single_player_df
# Out:
#       Unnamed: 0          id                       name  year_published  \
# 8              8  VNDvLYnE5o                Chrononauts            2000
# 24            24  aSIC1If5lf               People Power            2000
# 27            27  UXmJW11uqk   Buffy the Vampire Slayer            2000
# 51            51  9UAIXY90SI                     Numero            2000
# 92            92  Dz1VkpwmuI  Think: Logic Logo Trainer            2000
# ...          ...         ...                        ...             ...
# 1986        1986  ye6eL4ZtQp        Rurik: Dawn of Kiev            2019
# 1990        1990  qTl7hcj1nu          Tiny Epic Tactics            2019
# 1991        1991  GGvHuT0Kk7                     Ragusa            2019
# 1992        1992  BEl5GIjyqZ                  Project L            2019
# 1998        1998  9SCuTPw0Kp            Black Rose Wars            2019
#
#       min_players  max_players    primary_publisher  \
# 8             1.0          6.0          Looney Labs
# 24            1.0          3.0            GMT Games
# 27            1.0          6.0          Jasco Games
# 51            1.0          3.0                  NaN
# 92            1.0          4.0                  NaN
# ...           ...          ...                  ...
# 1986          1.0          4.0    PieceKeeper Games
# 1990          1.0          4.0        Gamelyn Games
# 1991          1.0          5.0                  NaN
# 1992          1.0          4.0         Boardcubator
# 1998          1.0          4.0  Ludus Magnus Studio
#
#                                               mechanics  num_user_ratings  \
# 8     [{'id': 'WPytek5P8l', 'url': 'https://www.boar...                42
# 24    [{'id': 'cznlFNKPA0', 'url': 'https://www.boar...                 1
# 27    [{'id': 'GNtouC8NLm', 'url': 'https://www.boar...                11
# 51                                                   []                 0
# 92    [{'id': 'ebJKldFVeS', 'url': 'https://www.boar...                 0
# ...                                                 ...               ...
# 1986  [{'id': '05zCZoLvQJ', 'url': 'https://www.boar...                12
# 1990  [{'id': '9mNukNBxfZ', 'url': 'https://www.boar...                10
# 1991  [{'id': 'AVY6EvSQTP', 'url': 'https://www.boar...                15
# 1992  [{'id': 'oeg6wN9Eoc', 'url': 'https://www.boar...                 2
# 1998  [{'id': 'PGjmKGi26h', 'url': 'https://www.boar...                 5
#
#       average_user_rating     rank  num_mechs
# 8                2.857143      911          3
# 24               0.000000  9999999          2
# 27               3.272727  9999999          4
# 51               0.000000  9999999          0
# 92               0.000000  9999999          2
# ...                   ...      ...        ...
# 1986             3.750000  9999999          4
# 1990             3.800000  9999999          4
# 1991             3.133333  9999999          2
# 1992             0.000000  9999999          4
# 1998             0.000000  9999999          8
#
# [353 rows x 12 columns]

# %%
Singledescription = Single_player_df.groupby('year_published')

# %%
#years = range(2000, 2021, 1)
#number = []
#count = 1
#for i in Single_player_df:
    #if Single_player_df['year_published'][i] != Single_player_df['year_published'][i+1]+1:
        #years.append([Single_player_df['year_published'][i+1]+1])
    #else:
        #years.append(Single_player_df['year_published'][i])
    #if Single_player_df['year_published'][i] == Single_player_df['year_published'][i+1]:
        #count += 1

# %%
ProtoLetstrythis = pd.DataFrame(Single_player_df['year_published'].value_counts(sort = False).reset_index())
Letstrythis = ProtoLetstrythis.rename(columns = {'year_published':'Minimum One Player Games %'})
Letstrythis['Other Minimum Player Count Games %'] = [95,96,94,91,96,94,94,93,89,84,81,84,80,79,82,75,67,58,57,58]
Letstrythis
# Out:
#     index  Minimum One Player Games %  Other Minimum Player Count Games %
# 0    2000                           5                                  95
# 1    2001                           4                                  96
# 2    2002                           6                                  94
# 3    2003                           9                                  91
# 4    2004                           4                                  96
# 5    2005                           6                                  94
# 6    2006                           6                                  94
# 7    2007                           7                                  93
# 8    2008                          11                                  89
# 9    2009                          16                                  84
# 10   2010                          19                                  81
# 11   2011                          16                                  84
# 12   2012                          20                                  80
# 13   2013                          21                                  79
# 14   2014                          18                                  82
# 15   2015                          25                                  75
# 16   2016                          33                                  67
# 17   2017                          42                                  58
# 18   2018                          43                                  57
# 19   2019                          42                                  58

# %%
Years = Letstrythis['index']
Counts = Letstrythis['Minimum One Player Games %']
MorePlayerCounts = Letstrythis['Other Minimum Player Count Games %']
#[5,4,6,9,4,6,6,7,11,16,19,16,19,17,17,22,31,42,43,37]
#plt.plot(Years, Counts, color = 'r')
#plt.title('Percentage of 1 Player (minimum) Games over Time')
#plt.xlabel('Year')
#plt.ylabel('Percentage of 1 Player games')
#plt.xticks(Years, rotation = 'vertical')
plt.plot( 'x', 'y1', data=df, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot( 'x', 'y2', data=df, marker='', color='olive', linewidth=2)
plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
# Out:
# ([<matplotlib.axis.XTick at 0x22e18b66a90>,
#   <matplotlib.axis.XTick at 0x22e18b66748>,
#   <matplotlib.axis.XTick at 0x22e18b66630>,
#   <matplotlib.axis.XTick at 0x22e18c125c0>,
#   <matplotlib.axis.XTick at 0x22e18c12a58>,
#   <matplotlib.axis.XTick at 0x22e18c12ef0>,
#   <matplotlib.axis.XTick at 0x22e18c193c8>,
#   <matplotlib.axis.XTick at 0x22e18c19860>,
#   <matplotlib.axis.XTick at 0x22e18c12fd0>,
#   <matplotlib.axis.XTick at 0x22e18c19828>,
#   <matplotlib.axis.XTick at 0x22e18c19e80>,
#   <matplotlib.axis.XTick at 0x22e18c23470>,
#   <matplotlib.axis.XTick at 0x22e18c23908>,
#   <matplotlib.axis.XTick at 0x22e18c23da0>,
#   <matplotlib.axis.XTick at 0x22e18c2c278>,
#   <matplotlib.axis.XTick at 0x22e18c2c710>,
#   <matplotlib.axis.XTick at 0x22e18c2cba8>,
#   <matplotlib.axis.XTick at 0x22e18c340f0>,
#   <matplotlib.axis.XTick at 0x22e18c2c668>,
#   <matplotlib.axis.XTick at 0x22e18c239b0>],
#  <a list of 20 Text major ticklabel objects>)

# %%
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(Years, Counts)
regress_values = Years * slope + intercept
line_eq = "y = " + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
plt.scatter(Years, Counts)
plt.plot(Years, regress_values, "r-")
plt.annotate(line_eq, (2000,30), fontsize=15, color='red')
print(f"The R value is : {rvalue}.")
plt.savefig('Images/One Player Game Scatter Plot')
# Out:
# The R value is : 0.9244623808367741.

# %%
plt.plot( 'x', 'y1', data=df, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot( 'x', 'y2', data=df, marker='', color='olive', linewidth=2)
plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
